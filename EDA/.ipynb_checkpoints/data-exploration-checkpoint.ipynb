# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_columns',False)
sns.set(rc={'figure.figsize':(20.7,8.27)})
sns.set_style("whitegrid")
sns.color_palette("dark")
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv('../data/data.csv')
df = df.drop(['Unnamed: 0','Unnamed: 0.1'], axis = 1)
df = df.drop_duplicates(subset = ['deskripsi'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25525 entries, 0 to 26372
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kamar_mandi    25525 non-null  object
#  1   kamar          25525 non-null  object
#  2   lb             24790 non-null  float64
#  3   lt             21072 non-null  float64
#  4   tipe_property  25525 non-null  object
#  5   price          25512 non-null  float64
#  6   sertifikat     25525 non-null  int64
#  7   deskripsi      25524 non-null  object
#  8   lokasi         25156 non-null  object
#  9   ada_garasi     25525 non-null  float64
#  10  pool           25525 non-null  int64
#  11  taman          25525 non-null  int64
#  12  electricity    24715 non-null  float64
#  13  floors_total   25341 non-null  float64
#  14  gym            25525 non-null  int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 3.1+ MB

# %% [markdown]
# Benerin tipe data

# %%
df = df.dropna(subset = ['price','lokasi'])

# %%
df[['pool','taman','gym','sertifikat']] = df[['pool','taman','gym','sertifikat']].astype('bool')

# %%
df['ada_garasi'] = df['ada_garasi'].apply(lambda x: True if x > 0 else False)

# %%
df = df[df['kamar']!='>10']

# %%
df['kamar'] = df['kamar'].astype('float')

# %%
df['kamar'] = df['kamar'].astype('int')

# %%
df = df[df['kamar_mandi'] != '>10']

# %%
df['kamar_mandi'] = df['kamar_mandi'].astype('float')

# %%
df['kamar_mandi'] = df['kamar_mandi'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25097 entries, 0 to 26372
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kamar_mandi    25097 non-null  int64
#  1   kamar          25097 non-null  int64
#  2   lb             24389 non-null  float64
#  3   lt             20811 non-null  float64
#  4   tipe_property  25097 non-null  object
#  5   price          25097 non-null  float64
#  6   sertifikat     25097 non-null  bool
#  7   deskripsi      25097 non-null  object
#  8   lokasi         25097 non-null  object
#  9   ada_garasi     25097 non-null  bool
#  10  pool           25097 non-null  bool
#  11  taman          25097 non-null  bool
#  12  electricity    24303 non-null  float64
#  13  floors_total   24918 non-null  float64
#  14  gym            25097 non-null  bool
# dtypes: bool(5), float64(5), int64(2), object(3)
# memory usage: 2.2+ MB

# %% [markdown]
# # Nilai masuk akal
# lantai max 60 (cek wiki)
#
# kamar max 100(kos2an masih masuk akal)
#
# kamar mandi 50(idem)

# %%
len(df[df['electricity']>50000])
# Out:
# 37

# %%
df = df[df['floors_total']<60]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24899 entries, 1 to 26372
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kamar_mandi    24899 non-null  int64
#  1   kamar          24899 non-null  int64
#  2   lb             24194 non-null  float64
#  3   lt             20621 non-null  float64
#  4   tipe_property  24899 non-null  object
#  5   price          24899 non-null  float64
#  6   sertifikat     24899 non-null  bool
#  7   deskripsi      24899 non-null  object
#  8   lokasi         24899 non-null  object
#  9   ada_garasi     24899 non-null  bool
#  10  pool           24899 non-null  bool
#  11  taman          24899 non-null  bool
#  12  electricity    24117 non-null  float64
#  13  floors_total   24899 non-null  float64
#  14  gym            24899 non-null  bool
# dtypes: bool(5), float64(5), int64(2), object(3)
# memory usage: 2.2+ MB

# %%
df = df[df['kamar_mandi']<30]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24667 entries, 1 to 26372
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kamar_mandi    24667 non-null  int64
#  1   kamar          24667 non-null  int64
#  2   lb             23970 non-null  float64
#  3   lt             20396 non-null  float64
#  4   tipe_property  24667 non-null  object
#  5   price          24667 non-null  float64
#  6   sertifikat     24667 non-null  bool
#  7   deskripsi      24667 non-null  object
#  8   lokasi         24667 non-null  object
#  9   ada_garasi     24667 non-null  bool
#  10  pool           24667 non-null  bool
#  11  taman          24667 non-null  bool
#  12  electricity    23892 non-null  float64
#  13  floors_total   24667 non-null  float64
#  14  gym            24667 non-null  bool
# dtypes: bool(5), float64(5), int64(2), object(3)
# memory usage: 2.2+ MB

# %%
df = df[df['kamar']<60]
df = df.reset_index()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24661 entries, 0 to 24660
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          24661 non-null  int64
#  1   kamar_mandi    24661 non-null  int64
#  2   kamar          24661 non-null  int64
#  3   lb             23965 non-null  float64
#  4   lt             20391 non-null  float64
#  5   tipe_property  24661 non-null  object
#  6   price          24661 non-null  float64
#  7   sertifikat     24661 non-null  bool
#  8   deskripsi      24661 non-null  object
#  9   lokasi         24661 non-null  object
#  10  ada_garasi     24661 non-null  bool
#  11  pool           24661 non-null  bool
#  12  taman          24661 non-null  bool
#  13  electricity    23886 non-null  float64
#  14  floors_total   24661 non-null  float64
#  15  gym            24661 non-null  bool
# dtypes: bool(5), float64(5), int64(3), object(3)
# memory usage: 2.2+ MB

# %%
# check margin of error *catatan = data masih mengandung outliers
# jumlah rumah tangga di jakarta = 2659205(bps) -> kurang lebih jumlah rumah/apartemen sama
# ga include keluarga yg ngekost sama anak gatau diri yg udah nikah masih nebeng ortu
# yekali sekeluarga ngemper
from math import sqrt
sqrt((2659205-len(df))/(2659205*len(df)))*100
# Out:
# 0.6338280824232521

# %% [markdown]
# Cek distribusi

# %%
num = [i for i in df.columns if (df[i].dtypes in ['int','float']) & (i != 'index')]
cat = [i for i in df.columns if (df[i].dtypes == 'O') | (df[i].dtypes == 'bool')]

# %%
for i in num:
    print(i)
    df[i].plot.hist()
    plt.show()
# Out:
# kamar_mandi
# kamar
# lb
# lt
# price
# electricity
# floors_total

# %%
for i in cat:
    if df[i].nunique()<100:
        print(i)
        df[i].value_counts().plot.bar()
        plt.show()
# Out:
# tipe_property
# sertifikat
# lokasi
# ada_garasi
# pool
# taman
# gym

# %%
df[num].describe()
# Out:
#         kamar_mandi         kamar  ...   electricity  floors_total
# count  24661.000000  24661.000000  ...  2.388600e+04  24661.000000
# mean       3.805645      4.783018  ...  7.304371e+03      2.098293
# std        2.365399      2.952104  ...  2.848695e+05      1.961095
# min        1.000000      1.000000  ... -1.000000e+00     -1.000000
# 25%        3.000000      3.000000  ...  2.000000e+03      2.000000
# 50%        3.000000      4.000000  ...  2.200000e+03      2.000000
# 75%        5.000000      5.000000  ...  4.400000e+03      2.000000
# max       29.000000     54.000000  ...  4.400350e+07     59.000000
#
# [8 rows x 7 columns]

# %%
sns.heatmap(df[df['tipe_property']=='Rumah'].drop('index',axis=1).corr(), annot = True)

# %% [markdown]
# Check median price distribution

# %%
df.groupby('lokasi')['price'].median().sort_values().plot.bar()
plt.show()

# %% [markdown]
# check mean price distribution

# %%
df.groupby('lokasi')['price'].mean().sort_values().plot.bar()
plt.show()

# %% [markdown]
# Statistical Check

# %%
from scipy import stats
lokasi = [i for i in df['lokasi'].unique()]
pair = {}
for i in lokasi:
    for j in lokasi:
        if j!=i:
            ttest = stats.ttest_ind(a = df[df['lokasi'] == i]['price'],
                                    b = df[df['lokasi'] == j]['price'])
            p_value = ttest.pvalue
            pair[f'{i} - {j}'] = p_value
    lokasi.remove(i)

# %%
count = 0
for i,j in pair.items():
    if j >= 0.05:
        count += 1
print(count, len(pair))
# Out:
# 172 651

# %% [markdown]
# Dari 651 kombinasi kecamatan, terdapat 210 pasangan kecamatan yang tidak memiliki perbedaan harga yang signifikan
# (benerin kata2nya)

# %%
for i,j in pair.items():
    if j >= 0.05:
        print(i)
# Out:
# Kebayoran Lama - Setiabudi
# Pancoran - Pasar Minggu
# Pancoran - Cilandak
# Pancoran - Penjaringan
# Pancoran - Kelapa Gading
# Pancoran - Senen
# Pancoran - Sawah Besar
# Pancoran - Taman Sari
# Pancoran - Cengkareng
# Pancoran - Kembangan
# Pancoran - Palmerah
# Pancoran - Kebon Jeruk
# Cilandak - Pasar Minggu
# Cilandak - Senen
# Cilandak - Sawah Besar
# Cilandak - Taman Sari
# Cilandak - Cengkareng
# Cilandak - Kembangan
# Cilandak - Palmerah
# Cilandak - Kebon Jeruk
# Pesanggrahan - Kelapa Gading
# Pesanggrahan - Pademangan
# Pesanggrahan - Cakung
# Pesanggrahan - Matraman
# Pesanggrahan - Jatinegara
# Pesanggrahan - Sawah Besar
# Pesanggrahan - Taman Sari
# Pesanggrahan - Kalideres
# Pesanggrahan - Grogol Petamburan
# Pesanggrahan - Tambora
# Jagakarsa - Koja
# Jagakarsa - Duren Sawit
# Jagakarsa - Kramat Jati
# Jagakarsa - Makasar
# Jagakarsa - Kemayoran
# Jagakarsa - Johar Baru
# Jagakarsa - Grogol Petamburan
# Tanah Abang - Mampang Prapatan
# Tanah Abang - Jatinegara
# Tanah Abang - Senen
# Tanah Abang - Gambir
# Tanah Abang - Taman Sari
# Tanah Abang - Palmerah
# Tanjung Priok - Tebet
# Tanjung Priok - Kelapa Gading
# Tanjung Priok - Pulo Gadung
# Tanjung Priok - Jatinegara
# Tanjung Priok - Cempaka Putih
# Tanjung Priok - Sawah Besar
# Tanjung Priok - Cengkareng
# Tanjung Priok - Kembangan
# Kelapa Gading - Pasar Minggu
# Kelapa Gading - Tebet
# Kelapa Gading - Pademangan
# Kelapa Gading - Koja
# Kelapa Gading - Matraman
# Kelapa Gading - Pulo Gadung
# Kelapa Gading - Makasar
# Kelapa Gading - Jatinegara
# Kelapa Gading - Senen
# Kelapa Gading - Cempaka Putih
# Kelapa Gading - Sawah Besar
# Kelapa Gading - Cengkareng
# Kelapa Gading - Kembangan
# Kelapa Gading - Kebon Jeruk
# Kelapa Gading - Tambora
# Koja - Cakung
# Koja - Duren Sawit
# Koja - Kramat Jati
# Koja - Matraman
# Koja - Makasar
# Koja - Kemayoran
# Koja - Johar Baru
# Koja - Sawah Besar
# Koja - Taman Sari
# Koja - Cengkareng
# Koja - Kalideres
# Koja - Grogol Petamburan
# Duren Sawit - Kramat Jati
# Duren Sawit - Makasar
# Duren Sawit - Kemayoran
# Duren Sawit - Johar Baru
# Duren Sawit - Grogol Petamburan
# Cipayung - Pasar Rebo
# Cipayung - Ciracas
# Ciracas - Pasar Rebo
# Pulo Gadung - Tebet
# Pulo Gadung - Pademangan
# Pulo Gadung - Jatinegara
# Pulo Gadung - Cempaka Putih
# Pulo Gadung - Sawah Besar
# Pulo Gadung - Taman Sari
# Pulo Gadung - Kembangan
# Pulo Gadung - Grogol Petamburan
# Pulo Gadung - Tambora
# Jatinegara - Pademangan
# Jatinegara - Cakung
# Jatinegara - Matraman
# Jatinegara - Senen
# Jatinegara - Cempaka Putih
# Jatinegara - Sawah Besar
# Jatinegara - Taman Sari
# Jatinegara - Cengkareng
# Jatinegara - Kembangan
# Jatinegara - Kalideres
# Jatinegara - Palmerah
# Jatinegara - Grogol Petamburan
# Jatinegara - Kebon Jeruk
# Jatinegara - Tambora
# Menteng - Cilincing
# Cempaka Putih - Tebet
# Cempaka Putih - Pademangan
# Cempaka Putih - Sawah Besar
# Cempaka Putih - Taman Sari
# Cempaka Putih - Kembangan
# Cempaka Putih - Grogol Petamburan
# Cempaka Putih - Tambora
# Sawah Besar - Pasar Minggu
# Sawah Besar - Tebet
# Sawah Besar - Pademangan
# Sawah Besar - Matraman
# Sawah Besar - Makasar
# Sawah Besar - Senen
# Sawah Besar - Taman Sari
# Sawah Besar - Cengkareng
# Sawah Besar - Kembangan
# Sawah Besar - Kalideres
# Sawah Besar - Palmerah
# Sawah Besar - Grogol Petamburan
# Sawah Besar - Kebon Jeruk
# Sawah Besar - Tambora
# Taman Sari - Pasar Minggu
# Taman Sari - Mampang Prapatan
# Taman Sari - Kebayoran Baru
# Taman Sari - Tebet
# Taman Sari - Setiabudi
# Taman Sari - Penjaringan
# Taman Sari - Cilincing
# Taman Sari - Pademangan
# Taman Sari - Pasar Rebo
# Taman Sari - Kramat Jati
# Taman Sari - Matraman
# Taman Sari - Makasar
# Taman Sari - Senen
# Taman Sari - Johar Baru
# Taman Sari - Gambir
# Taman Sari - Cengkareng
# Taman Sari - Kembangan
# Taman Sari - Kalideres
# Taman Sari - Palmerah
# Taman Sari - Kebon Jeruk
# Taman Sari - Tambora
# Kembangan - Pasar Minggu
# Kembangan - Tebet
# Kembangan - Penjaringan
# Kembangan - Senen
# Kembangan - Cengkareng
# Kembangan - Palmerah
# Kembangan - Kebon Jeruk
# Kembangan - Tambora
# Palmerah - Pasar Minggu
# Palmerah - Penjaringan
# Palmerah - Senen
# Palmerah - Gambir
# Palmerah - Cengkareng
# Palmerah - Kebon Jeruk
# Kebon Jeruk - Pasar Minggu
# Kebon Jeruk - Tebet
# Kebon Jeruk - Penjaringan
# Kebon Jeruk - Senen
# Kebon Jeruk - Cengkareng
# Kebon Jeruk - Tambora
