# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_columns',False)
sns.set(rc={'figure.figsize':(20.7,8.27)})
sns.set_style("whitegrid")
sns.color_palette("dark")
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv('../data/data.csv')
df = df.drop(['Unnamed: 0','Unnamed: 0.1'], axis = 1)
df = df.drop_duplicates(subset = ['deskripsi'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25525 entries, 0 to 26372
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kamar_mandi    25525 non-null  object
#  1   kamar          25525 non-null  object
#  2   lb             24790 non-null  float64
#  3   lt             21072 non-null  float64
#  4   tipe_property  25525 non-null  object
#  5   price          25512 non-null  float64
#  6   sertifikat     25525 non-null  int64
#  7   deskripsi      25524 non-null  object
#  8   lokasi         25156 non-null  object
#  9   ada_garasi     25525 non-null  float64
#  10  pool           25525 non-null  int64
#  11  taman          25525 non-null  int64
#  12  electricity    24715 non-null  float64
#  13  floors_total   25341 non-null  float64
#  14  gym            25525 non-null  int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 3.1+ MB

# %% [markdown]
# Benerin tipe data

# %%
df = df[df['tipe_property']=='Rumah']

# %%
df = df.dropna(subset = ['price','lokasi'])

# %%
df[['pool','taman','gym','sertifikat']] = df[['pool','taman','gym','sertifikat']].astype('bool')

# %%
df['ada_garasi'] = df['ada_garasi'].apply(lambda x: True if x > 0 else False)

# %%
df['kamar'] = df['kamar'].apply(lambda x:0 if x == '>10' else x)
df['kamar_mandi'] = df['kamar_mandi'].apply(lambda x:0 if x == '>10' else x)
df[['kamar','kamar_mandi']] = df[['kamar','kamar_mandi']].astype('float')
df[['kamar','kamar_mandi']] = df[['kamar','kamar_mandi']].astype('int')

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18230 entries, 0 to 18229
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          18230 non-null  int64
#  1   kamar_mandi    18230 non-null  int64
#  2   kamar          18230 non-null  int64
#  3   lb             17972 non-null  float64
#  4   lt             17830 non-null  float64
#  5   tipe_property  18230 non-null  object
#  6   price          18230 non-null  float64
#  7   sertifikat     18230 non-null  bool
#  8   deskripsi      18230 non-null  object
#  9   lokasi         18230 non-null  object
#  10  ada_garasi     18230 non-null  bool
#  11  pool           18230 non-null  bool
#  12  taman          18230 non-null  bool
#  13  electricity    17686 non-null  float64
#  14  floors_total   18076 non-null  float64
#  15  gym            18230 non-null  bool
# dtypes: bool(5), float64(5), int64(3), object(3)
# memory usage: 1.6+ MB

# %%
df['floors_total'].describe()
# Out:
# count    18076.000000
# mean         3.375636
# std         60.031857
# min         -1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max       3500.000000
# Name: floors_total, dtype: float64

# %%
import re

# %%
def listrik(df):    
    df['electricity_desc'] = np.zeros(len(df))
    for i in range(len(df)):
        text = str(df['deskripsi'].iloc[i]).lower().replace('.','').replace(',','')
        try:
            cari = re.search('listrik',text)
            S = cari.span()
            txt = text[S[1]:S[1]+15]
            clean = re.findall(r'[^\D]+',txt)
            clean = [int(i) for i in clean]
            if re.search(r'x',txt):
                clean = clean[0]*clean[1]
            elif (len(clean)>=2) &( (len(str(clean[1]))<=2) | (len(str(clean[0]))<=2)):
                clean = clean[np.argmax(clean)]
            else:
                clean = sum(clean)
        except:
            try:
                cari = re.search('watt',text)
                S = cari.span()
                txt = text[S[1]-10:S[1]]
                clean = re.findall(r'[^\D]+',txt)
                if re.search(r'x',txt):
                    clean = clean[0]*clean[1]
                elif  (len(clean)>=2) &( (len(str(clean[1]))<=2) | (len(str(clean[0]))<=2)):
                    clean = clean[np.argmax(clean)]
                else:
                    clean = sum(clean)
            except:
                try:
                    cari = re.search('va ',text)
                    S = cari.span()
                    txt = text[S[1]-8:S[1]]
                    clean = re.findall(r'[^\D]+',txt)
                    if re.search(r'x',txt):
                        clean = clean[0]*clean[1]
                    elif (len(clean)>=2) &( (len(str(clean[1]))<=2) | (len(str(clean[0]))<=2)):
                        clean = clean[np.argmax(clean)]
                    else:
                        clean = sum(clean)
                except:
                    clean = 0
        df['electricity_desc'].iloc[i] = clean
    return df

# %%
df = listrik(df)
# Out:
# /Users/rhzphlv/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
for i in range(len(df)):
    try:
        int(df['electricity_desc'].iloc[i])
    except:
        print(i)
        print(df['deskripsi'].iloc[i])
        print(df['electricity_desc'].iloc[i])

# %%
df['electricity_desc'] = df['electricity_desc'].astype('int')

# %%
df['electricity_desc'].value_counts().sort_values().head(100)
# Out:
# 14400        1
# 500          1
# 44000        1
# 3650         1
# 16600        1
#          ...
# 1300        50
# 4400        59
# 3500        77
# 2200       167
# 0        17595
# Name: electricity_desc, Length: 80, dtype: int64

# %%
count=0
for i in range(len(df)):
    if df['electricity_desc'].iloc[i]%100!=0:
        print(df['deskripsi'].iloc[i])
        print(df['electricity_desc'].iloc[i])
        print(i)
        count+=1
print(count)
# Out:
# rumah dalem cluster lt. : 116m lb. : 160m suratnya : shm kt. : 3+1 km: 4+1 watt : 2200 lebar dpn : 6,7m panjang ke blkng : 17m fasilitas apa saja tuk per_unitnya : carport 2 mobil, instalasi air panas, free kitchen set lebar jalan dpn : 5,5m harga jual : 2,500.000.000
# 4
# 212
# rumah dalem cluster siap huni  3unit lagi  lt. : 116m lb. : 160m suratnya : shm kt. : 3+1 km: 4+1 watt : 2200 lebar dpn : 6,7m panjang ke blkng : 17m fasilitas apa saja tuk per_unitnya : carport 2 mobil, instalasi air panas, free kitchen set lebar jalan dpn : 5,5m harga jual : 2,7m
# 4
# 224
# rumah dalem cluster siap huni  4 unit lagi bebas milih   4 unit lagi lt. : 116 m2 lb. : 160 m2 suratnya : shm kt. : 3+1 km: 4+1 watt : 2200 lebar dpn : 6,7 m panjang ke blkng : 17 m fasilitas apa saja tuk per unitnya : carport 2 mobil, instalasi air panas, free kitchen set lebar jalan dpn : 5,5m harga jual : rp 2.700.000.000
# 4
# 264
# karang tengah, lebak bulus jaksel dijual rumah siap huni dalam cluster 32 unit ready dan indent cilandak lebak bulus jakarta selatan unit ready dan indent , lokasi strategis, dekat ke mrt, area komersil dan kuliner, akses tol dan sarana umum lainnya. bangunan 2 lantai luas tanah : 116 luas bangunan : 160 legalitas : shm kamar tidur : 3+1 kamar mandi : 4+1 watt : 2200 fasilitas: carport 2 mobil, instalasi air panas, free kitchen set. starting harga  2,3 m nego - 3 m nego harga tergantung style rumah more info : masodah
# 4
# 346
# townhouse exclusive hanya 6 rumah di ragunan pasar minggu jaksel, lokasi strategis dekat ke toll ampera, tb simatupang, rsud ps minggu, kemang dll
# hanya tinggal 4 unitlt. 256m², lb. 410m² rp. 7,5 mkamar 4+2, k.mandi 4+2, tamancarport 4 mobillistrik 2200w
# dijual rumah kos  kosan hook 10 kt luas 163 m2 parkir luas di jalan tomang asli jakarta barat  luar tanah : 163 m2 lebar depan : 9.5 m2 lebar belakang : 10.5 m2 panjang : 16.34 m2 luas bangunan : 225 m2 sertifikat : shm muat parkir 7 mobil air : jet pum ada 10 kamar kost terisi semua tiap kamar punya khw listrik masing2 daya 1300 watt listrik main house memiliki daya 4400 watt masing2 kamar kost berisi : ac 1.5 pk, tempat tidur + kasur spring bed, lemari kaca, meja belajar + kursi. dapur bersama di lantai 1 dan disediakan 1 buah kulkas bersama. lantai 4 berupa rooftop untuk cuci dan jemur baju. kamar mandi di luar semua. tiap lantai 1 kamar mandi dengan shower.  harga jual: 5.5 m (nego)  for more info contact: nyoman hp & wa :  re/max premier cideng
# 2
# 7965
# dijual rumah kost hotel terisi penuh di jln mangga besar jakarta barat  - kost baru 18 kamar dgn nett roi 9% - 11% ++ / thn  net income 420 jutaan/thn  spesifikasi :  bangunan 4,5 lantai  luas tanah 84 m2 (4x21) luas bangunan 320 m2  kamar tidur 18+1 kamar mandi 18+1  - shm, imb, pbb - akses jalan 2 mobil lega - hadap timur   notes :  - harga kamar 2,1 jta s.d 2,8 juta /bulan - orang kedua + 500.000 / bulan    fasilitas & tipe kamar :  1. kamar deluxe (3x3meter) dg kasur 100cm, shower + toilet duduk harga 2,1jt  2. kamar deluxe plus (jendela) dg kasur 100cm, shower, toilet duduk harga 2,2jt  3.kamar suite ( kamar lebih luas dari deluxe plus jendela) dg kasur 100 cm shower,toilet duduk harga 2,4 jta  4. kamar suite double dg kasur 160 cm, queen size, shower, toilet duduk harga 2,8jt  5. komplit dengan : ac, token masing2 1300watt, kamar mandi dalam, air panas, toilet duduk, lemari + cermin besar, android smart tv 32 + meja + kursi lengkap dg lampu tiang utk tidur & belajar/kerja, panel cermin dinding besar.  fasilitas umum all in :  1. wifi kenceng dg router pribadi di setiap masing2 kamar (dg sistem mikrotik spti hotel) 2. laundry 4pcs perhari 3. air minum dispenser 4. dapur (gas gratis) +  microwave + kulkas bersama + ruang makan  5. room cleaning service 1minggu 1x 6. parkir 9 motor, mobil parkir dijalan 7. gerbang dan cctv 24jam. 8.  ruang kerja/belajar khusus utk wfh di lantai5  parkir motor -+ 10  - rata2 setiap bulan terisi 90-100% meskipun pandemi  - net income sekarang 35 juta / bulan  - + potensi income tambahan 2jt/bln (jika kost berdua) - + potensi di naikin harga skitar 200rb/kmr total 3,6jt/bln krn hrga skrg adalah masih harga diskon pandemi  harga 4,9 m nego  utk info hub : agus supriyanto tlp/wa  ||  instagram @rumaindoaja
# 2
# 8222
# ['dijual rumah 2 lantai di cipinang muara,jatinegara,jakarta timur', none, ' ', 'luas tanah 175 m2', 'luas bangunan 260 m2.', 'sertifikat hak milik / imb', none, 'harga 3,7 m nego dikit', none, 'listrik pln 10 amp 2200 watt.', 'air pam aetra.', none, '4 kamar tidur 3 kamar mandi', '1 kamar pembantu & 1 kamar mandi pembantu', 'garasi  1 mobil', 'carport 2 mobil', none, 'info detail dan janjian survey ', 'hubungi : kang sahil']
# 220
# 8517
# ['dijual rumah di pondok jaya, mampang prapatan, jakarta selatan', none, 'lt 200m', 'lb 200m', '2 lantai', 'kt 4+1', 'km 4+1', 'listrik', 'lantai 1 = 2,200 watt', 'lantai 2 = 2,200 watt', 'garasi + carport', 'hadap barat', 'shm', none, 'harga = idr 6.5 m (nego)']
# 2
# 8656
# ['dijual rumah', 'di jalan bungur 2 no.31, dekat pusat perbelanjaan (pondok indah mall, pasar kebayoran lama, gandaria city mall, pakubuwono residance ).', 'rumah terbagi menjadi 2 kontrakan. luas tanah keseluruhan 102 mtr. ada 1 kamar tambahan di lantai 2. ada 2 rekening listrik, 1 pam, 1 jetpam. sertifikat hak milik. lingkungan rumah nyaman dan bersih. bukan daerah banjir. akses angkot d 01, apb ke mayestik, deborah kalideres, s41 trans bsd, ac 73. ', 'yang minat bisa hubungi kontak yg tertera.', none, 'harga bisa nego']
# 1
# 8730
# Rumah Mewah Dengan Fasilitas Kolam Renang Pribadi di Pusat Kota Cempaka Putih Jakarta Pusat:Dijual Rumah Siap Huni di Cempaka Putih Jakarta Pusat
#
# Luas tanah 600
# Luas bangunan 800
# Kamar tidur 4+3
# Kamar mandi 5+1
# SHM
# Listrik 16rb
# Garasi 5 mobil
# AC 9 unit
# Kitchen set
# Water Heater 2 unit
# Air PAM & Tanah
#
# Harga 13,5 M nego
#
# Hubungi
# Titis Era Sky
# 08113200521
# 16
# 10075
# Rumah Mewah Besar Kawasan Elite Pegangsaan Menteng Jakarta Pusat:Rumah Mewah Besar siap huni kawasan Elite Pegangsaan Menteng Jakarta Pusat.
# Luas Tanah 537 m2
# Luas Bangunan 1100 m2
# Bangunan 2 lantai
# SHM
# Kamar Tidur 8 + 4
# Kamar Mandi 6 + 2
# Hadap Timur
# 5 kmr tidur ( lt bawah)
# 3 kmr tidur (lt atas)
# 4 kmr tidur (lt atas service)
# Garasi + Carport 7 mobil
# Taman depan dan Taman belakang
# Ruang keluarga
# Ruang makan
# Ruang tamu
# Voyer
# Dapur kotor dan dapur bersih
# Listrik 10 000 watt
# Gas Alam
# PDAM/Pompa
#
# Harga Rp. 29,5 M Nego
#
# Contact / WA :
# 0813 8463 7817 Elisabeth
# 0813 8232 3744 Dion
# 10
# 10148
# Promo HARGA CORONA Rumah Kos 106 Kamar Jl. Kramat, Jakpus, BONUS RuKost 9 KT di Pademangan, Jakut:Investasi PASTI UNTUNG, di jual rumah Kosant 106 Kamar TERISI Full 100% OMZET ISTIMEWA di sekitar Salemba, Jakarta Pusat.
#
# Spesifikasi:
# - Luas bangunan: 1.400 M2
# - Luas Tanah: 774 M2
# - Jumlah Kamar: 108 + 3
# - Kamar Mandi: 60
# - Legalitas: SHM + IMB + PBB
# - Air: 2 Mesin Jet Pump
# - Torrent: 1
# - Air Conditiner: 60
# - Listrik Token: 105 + 1 (@1300 Watt/Kamar)
# - CCTV: 12 Titik
#
# Fasilitas:
# * TV
# * Internet
# * Mesin Cuci
# * Dapur
# * Kulkas
# * Parkiran
# * Tempat Jemuran
#
# Noted:
# Promo HARGA CORONA Rumah Kos 105 Kamar Jl. Kramat, Jakpus, GRATIS Rumah Kost 9 kamar, seharga 2,6 M di Pademangan, Jakut
#
# # Harga: 25 M Nego #
#
# Untuk informasi lebih lanjut, hubungi:
#
#
# Joko
# 0878 8045 1777
# 0812 8613 846
# 105
# 10354
# Rumah Kost Jakarta Pusat:point seling unit :
#
# 1. Income sampai dengan 170 juta /bln
# 2. Posisi dibelakang hotel acacia senen
# 3. Harga pasaran diatas 27M Dijual 22.750 M
# 4. Kamar 105
# 5. Sudah token listrik 105
# 6. Unit sudah renovasi jadi tidak perlu renovasi
# 7. Parkir luas untuk 100 motor lebih
# 8. Sudah access card
# 9. Tersedia CAFE
# 10. Tersedia mesin cuci ,WIFI gratis
# 11. Depan jalan 2 mobil
# 12. Bangunan 4 lantai
# 13. Lantai 4 bisa di upgrade jadi 25 kamar lagi
# 14. Access 16 CCTV online
# 15. Full okupansi full furnished
# 105
# 10447
# Rumah kost dahsat,harga murah untung berlipat di keramat jakarta pusat:Dijual
# Mau lebih kaya raya beli
# Rumah kost 105 pintu di kramat senin
# Jakarta pusat
# Luas tanah 774 m2
# Luas bangunan 1500 m2
# Kamar tidur 105
# Ad 4 lt
# Sudah token msing" @1.300/kmr
# Kamar mandi 89
# Penghasilan sekitar Rp.170 juta
# Legalitas
# SHM ,imb, pbb
# Air ,tanah
# Kondisi kost skrng aktif dan full semua
#
# 15 point seling Kramat
#
# 1. Income sampai dengan 170 juta /bln
# 2. Posisi dibelakang hotel acacia senen
# 3. Harga pasaran diatas 27M Dijual 22.750 M
# 4. Kamar 105
# 5. Sudah token listrik 105
# 6. Unit sudah renovasi jadi tidak perlu renovasi
# 7. Parkir luas untuk 100 motor lebih
# 8. Sudah access card
# 9. Tersedia CAFE
# 10. Tersedia mesin cuci ,WIFI gratis
# 11. Depan jalan 2 mobil
# 12. Bangunan 4 lantai
# 13. Lantai 4 bisa di upgrade jadi 25 kamar lagi
# 14. Access 16 CCTV online
# 15. Full okupansi & full furnished
# Harga Rp.22.750 M ( Net )
# Hub Supinda Wijaya
# Era Star
# WA : 085777926700
# Simpati : 081382149501
# 105
# 10476
# Rumah Siap Huni di Jln. Cilamaya, Cideng Barat, Jakarta Pusat, Jakarta:Jln. Cilamaya, Cideng Barat, Jakarta Pusat, Jakarta
# Rumah Siap Huni Dijual Cepat di Jln. Cilamaya, Cideng Barat, Jakarta Pusat, Jakarta
#
# Spesifikasi:
# Luas tanah: 349 m2
# luas bangunan: 316 m2
# Listrik: 16 kVA
# SHM
#
# 2 lantai
# Terdiri dari:
# 2 (dua) ruangan utama living room besar dilantai 1 dan lantai 2
# 4 (empat) kamar / ruang kerja
# 1 (satu) ruang pertemuan (meeting room)
# 1 (satu) pantry
# 2 (dua) kamar mandi utama
# 2 (satu) kamar mandi services
# 1 (satu) kamar tidur services
# 1 (satu) Gudang ruang penyimpanan
# 1 (satu) garasi, 4 (empat) carport
# Unit Genset 16 kVA sebagai pembangkit listrik backup
#
# Deskripsi:
# Rumah Modern Minimalis, sangat nyaman dengan desain eco-living modern minimalis yang 100% didesain dengan rapih dan nyaman, bersih & sangat mendukung kenyamanan aktifitas dan rutinitas Anda, dan lokasi strategis di pusat Kota Jakarta
#
# Rp. 11.900.000.000 nego
#
# Info lebih lanjut hubungi:
# Lien Lee
# 082123831424
# ERA SKY Summarecon B
# 16
# 10538
# -Lokasi Masih Asri dengan pemandangan danau buatan dan kolam Arwana
# -Sudah Cakar Ayam
# -Di lalui jalur Angkutan Umum (T15)
#
# Type Mulai 40/60, 40/72, 45/84, 45/90, 56/84, 56/90
#
# Spesifikasi
# Pondasi : cakar ayam, sloof bertulang besi 10mm
# Dinding : double hebel 10 cm, finishing cat
# Lantai : keramik 60 x 60 cm
# Atap : Rangka Baja Ringan, Genteng Flat Beton
# Plafond : Gypsum Board, Finishing Cat
# Kamar Mandi : dinding lantai keramik, closet duduk
# Dapur : Kitchen sink satu lubang, dinding keramik
# pintu utama : panel solid kamper / setara
# pintu kamar : durian / setara
# WC : PVC / setara
# Kaca : rayban 5mm
# Carport : rabat beton
# Listrik : PLN 1300 2200 watt
# 1520
# 11532
# Jakarta Barat Rumah Kos Bebas banjir Jelambar dekat kampus selalu penuh(JL71):Rumah Kos Bebas banjir Jelambar dekat kampus selalu penuh(JL71)
#
# Dijual Cepat kos latumenten daerah strategis
#
# dekat ke HALTE BUSWAY
#
# dekat ke Stasiun Kereta
#
# 10 Menit ke Kampus Trisakti dan UNTAR
#
# dekat Mall Taman Anggrek, Central Park, Season City
#
# banyak mini market, warung makan, transportasi di sekitar
#
# 7 kamar kos selalu full terisi sewa 900rb-1,5jt/bulan
#
# Bangunan 2,5 lantai masih baru dan kokoh.
#
# Bebas banjir krn sudah ditinggikan
#
# Luas tanah 63m
#
# Luas bangunan 108m
#
# Lebar jalan depan 1,5 mobil
#
# Air PAM dan Tanah
#
# Biaya bulanan :
#
# Listrik 80rb -90rb
#
# Air pam 25rb
#
# Line telpon 30rb
#
# Bonus:
#
# anak kos dan isi didalamnya
#
# 3 unit AC
#
# 3 unit token listrik
#
# Ranjang, lemari, kursi
#
# Filter air Tanah
#
# SHM + IMB + PBB lengkap
#
# Cocok untuk invest jangka panjang, maupun keluarga muda, kos tinggal dilanjutin aja atau dijadikan rumah tinggal atau mes karyawan pun bisa
#
# bagi anda yang sedang mencari rumah baru,rumah tua
# daerah tanjung duren,taman ratu,jelambar,grogol,tomang,kemanggisan
# silahkan hubungi kami
#
# hu
# 90
# 13168
# Rumah kost di Latumenten lokasi strategis, jakarta barat UB,:Dijual cepat rumah kost lokasi strategis di latumenten jakarta barat
#
# Shm, imb dan pbb
# Luas tanah 63m2
# Luas bangunan 108m2
# 2,5 lantai bangunan masih baru dan kokoh
# 7 kamar tidur
# 1 kamar mandi
# Air pam dan tanah
# Kamar selalu terisi full dengan harga per kamar 900rb s/d 1,5jt / bulan
# Bebas banjir krn sdh ditinggikan
# Lebar jalan depan 1,5 mobil
#
# Biaya bulanan
# Listrik 90rb
# Air pam 25rb
# Line telepon 30rb
#
# Bonus
# Anak kost dan isi di dalamnya
# 3 unit ac
# 3 unit token listrik
# Ranjang, lemari, kursi
# Filter air
#
# Lokasi strategis
# Dekat halte busway
# Dekat stasiun kereta
# Dekat kampus Trisakti dan untar
# Dekat mall central park dan season city
#
# Dijual harga 2,3M nego
# 90
# 13342
# rumah murah daerah kota kebon jeruk siap huni.:dijual segera rumah murah bukan murahan, kondisi siap huni / sudah renov rapi.
# lokasi kebon jeruk / kota
# uk. 6x10
# 3lt
# vocher listrik
# 4kt / 2km
# 2 gudang
# shm
# harga 1,550 nego
#
# lokasi unit masuk komplek kecil bebas banjir, aman , mobil bs parkir dalam.
# jalanan luar bs lewat mobil besar.
#
# hub. vick
# 08993616188 wa / call
# 082125236161
# 4
# 13791
# Rumah Cantik Strategis Sunrise Garden Kedoya Utara Kebon Jeruk Jakarta Barat:Rumah multifungsi (bisa untuk rumah tinggal atau dengan usaha)
# Lokasi strategis BEBAS BANJIR & dekat berbagai fasilitas.
# Lokasi boulevard Sunrise Garden. Posisi rumah tinggi dari jalan & hook ventilasi bagus
# Hadap Timur dan Selatan mendapat sinar matahari pagi yg menyehatkan.
# Luas Tanah 465 m2 (19x24.5m)
# Luas Bangunan 565 m2
# Lantai 2,5 lt
# Surat lengkap: SHM, IMB, PBB dll
# Listrik : 2 panel ( 11000 & 7700 watt)
# Telepon : 2 line
# Air PDAM dan air tanah
# AC Lt 1 ( 9 unit) & Lt 2 (9 unit)
# CCTV : 2 decoder (total 32 kamera)
# Parkir : garasi 1 mobil, carpot 14 mobil
#
# Harga Rp.12,9 M Nego
#
# Contact/WA:
# 0813 8463 7817 Elisabeth
# 0813 8232 3744 Lamtor
# 11
# 13916
# Dijual Rumah Semi Furnished di Bukit Gading Mediterania Kelapa Gading:Rumah Uk 12x26m2, Luas Tanah 312m2 dan Luas Bangunan 600m2.
#
# Highceiling, open space, terang, udara mengalir sempurna
#
# 2 1/2 lantai, Tinggi plafon 5 meter.
#
# 2 kamar tidur utama (1dibwh 1diatas) dan 2 kamar tidur anak.
#
# 1 kmr tamu/kantor, 5 kmr mandi (4didalam 1diluar)
#
# 2 kmr tidur PRT dan 1 Kmr mandi PRT. Dapur kotor
#
# 1 garasi, Listrik 10rb va (3phase), Solarhart. Semi furnished (furniture yang nempel)
#
# Harga 14,5 Milyar nego
#
#
#
# Hubungi :
#
# Uke Dana 0812 1100 220
#
# Ray White Jakarta Garden City
# 10
# 14372
# RUMAH. JL. SUNGAI TIRAM GG H. ABDUROHIM. CILINCING MARUNDA , JAKARTA UTARA:RUMAH. JL. SUNGAI TIRAM GG H. ABDUROHIM. CILINCING MARUNDA , JAKARTA UTARA
# Jual Rumah
# JL. SUNGAI TIRAM GG. ABDUROHIMRT 01 / RW 04CILINCING, MARUNDAJAKARTA UTARA
# LT 70 LB 70
# KT 3 KM 1
# Dimensi 7 x 10
# Listrik 450 Watt
# Rp 400,000,000
# SHM
# Hadap Barat
#
# Hubungi :
# EDDY (MCC) - BRKG
# 0878 8799 2136
# 450
# 15338
# RUMAH. JL. SUNGAI TIRAM GG H. ABDUROHIM. CILINCING MARUNDA , JAKARTA UTARA:RUMAH. JL. SUNGAI TIRAM GG H. ABDUROHIM. CILINCING MARUNDA , JAKARTA UTARA
# Jual Rumah
# JL. SUNGAI TIRAMGG. ABDUROHIMRT 01 / RW 04CILINCING, MARUNDAJAKARTA UTARA
# LT 70 LB 70
# KT 3 KM 1
# Dimensi 7 x 10
# Listrik 450 Watt
# Rp 400,000,000
# SHM
# Hadap Barat
#
# Hubungi :
# FERO (MCC) - BRKG
# 0878 7773 4318
# 450
# 15397
# RUMAH SIAP HUNI DI LEBAK BULUS DALEM CLUSTER:Rumah Dalem cluster
# Bonus AC
# Lt. : 116m
# Lb. : 160m
# Suratnya : SHM
# Kt. : 3+1
# Km: 4+1
# Watt : 2200
# Lebar dpn : 6,7m
# Panjang ke blkng : 17m
# Fasilitas apa saja : carport 2 mobil, instalasi air panas, ada kitchen set
# Lebar jalan dpn : 5,5m
# Harga jual : 2,7m nego Ratusan juta
# 4
# 15414
# Rumah Baru Di Lebak Bulus Dalem cluster:Rumah Dalem cluster
# Lt. : 116m
# Lb. : 160m
# Suratnya : SHM
# Kt. : 3+1
# Km: 4+1
# Watt : 2200
# Lebar dpn : 6,7m
# Panjang ke blkng : 17m
# Fasilitas : carport 2 mobil, instalasi air panas, free kitchen set
# Lebar jalan dpn : 5,5m
# Harga jual : 2,6m nego
# 4
# 15426
# RUMAH SIAP HUNI DI LEBAK BULUS DALEM KOMPLEK:Rumah Dalem cluster
# Lt. : 116m
# Lb. : 160m
# Suratnya : SHM
# Kt. : 3+1
# Km: 4+1
# Watt : 2200
# Lebar dpn : 6,7m
# Panjang ke blkng : 17m
# Fasilitas : carport 2 mobil, instalasi air panas, free kitchen set
# Lebar jalan dpn : 5,5m
# Harga jual : 2,500.000.000
# 4
# 15941
# RUMAH 2LT LUAS 106 M2, NEMPEL RAGUNAN-CILANDAK:[FOR SALE]
# RUMAH 2 LANTAI DI KEDONDONG JAGAKARSA
# STRATEGIS, LOKASI ASRI, BEBAS BANJIR,
# AREA TERDEPAN, NEMPEL RAGUNAN-CILANDAK
#
# Rumah 2 Lantai
# Legalitas : SHM, IMB, PBB Lengkap
# LB : 150 M2 | LT : 106 M2 |
# KT : 3+1 | KM : 3+1 | Carport 1 mobil |
#
# Teras - R. Tamu - R. Keluarga - Dapur
# Taman belakang - R. Jemur khusus
# Listrik 2.200W
#
# IDR. 1.775 M (NEGO)
#
# HUB : ARIF. H
# 0812-1354-2601
#
#
#
#
#
#
#
#
# Tag(s) : Jagakarsa, Ciganjur, Cipedak, Lenteng agung, Srengseng sawah, Tanjung barat, TB Simatupang, Pasar minggu, Pejaten barat, Pejaten timur, Kebagusan, Jati Padang, Ragunan, Cilandak, Cipete, Gandaria Selatan, Lebak bulus, Pondok labu, Cinere, Mampang prapatan, Kalibata, Pancoran, Fatmawati, Ampera, Kemang, Pondok indah, Kebayoran baru, Senayan, Kebayoran lama, Pesanggrahan, Setiabudi, Tebet
# 2377
# 16875
# milikilah rumah aman dan nyaman di kawasan ring 1 istana negara dan berada di seberang komplek paspampres !!!
#
#
#
# rumah siap huni di petojo, gambir, jakarta pusat.
#
# luas tanah : 12x22.5
#
# sertifikat : sertifikat hak milik
#
# kamar : 6 kamar tidur dan 2 kamar mandi
#
# carport : 1 mobil
#
# air : air pam
#
# listrik : 3500 dan 2200 watt
#
# jalan depan rumah lega 2 mobil
#
#
# harga rumah :15.2 milyar
#
# (nego sampai deal)
#
# alasan kenapa anda harus membeli rumah ini :
#
#
# 1. garansi tidak pernah banjir
#
# 2. dekat kompleks paspampres ri
#
# 3. masuk kawasan ring 1 istana negara
#
# 4. jalan bisa dilalui truk engkel
#
# 5. dekat dengan pusat kuliner, minimarket, dan akses kawasan rumah
#
# bisa dilalui ojek daring dan angkutan kota (angkot),
#
# 6. akses ke pusat bisnis dan perbelanjaan radius 2-3.5 km :
#
# 6 menit ke pasar tanah abang
#
# 8 menit ke plaza indonesia
#
# 10 menit ke sarinah
#
# 11 menit ke mall taman anggrek
#
# 11 menit ke central park
#
# 11 menit ke mall ciputra
#
#
#
# akses ke sekolah dan universitas radius 2 km:
#
# 7 menit ke smpn 72 jakarta
#
# 7 menit ke sekolah ketapang jakarta
#
# 8 menit ke smak 2 bpk penabur pintu air
#
# 8 menit ke universitas trisakti
#
# 9 menit ke universitas tarumanagara
#
# 11 menit ke universitas kristen krida wacana
#
#
#
# akses ke rumah sakit radius 1 km :
#
# 4 menit ke rs tarakan
#
# 11 menit ke rs abdi waluyo, menteng
#
# 13 menit ke rspad gatot subroto
#
#
#
# akses ke kawasan pemerintahan :
#
# 4 menit ke kawasan mahkamah konstitusi republik indonesia
#
# 4 menit ke kementrian perhubungan republik indonesia
#
# 4 menit ke kementrian komunikasi dan informasi republik indonesia
#
# 6 menit ke kementrian pertahanan republik indonesia
#
# 6 menit ke bank indonesia
#
# 6 menit ke kementrian koordinator bidang politik, hukum, dan keamanan republik indonesia
#
# 7 menit ke museum nasional
#
# 9 menit ke kementrian perdagangan republik indonesia
#
#
#
# musibah banjir rob 5 juni 2020 dan penurunan tanah di pesisir utara jakarta bakal membuat harga tanah di jakarta pusat (yg tidak pernah banjir) menjadi naik drastis.
#
#
#
# memiliki rumah/tanah di jakarta pusat dan tidak pernah banjir akan menjadi investasi yg sangat menguntungkan bagi anda.
#
#
# hubungi : efendi tobing
# 3720
# 17245
# dijual rumah jatinegara jakarta timur, akses jalan 2 mobil , dekat dengan terminal . siap kpr, bebas banjir , lingkungan aman nyaman.
# spesifikasi sbb:
# jl wedana dalam jatinegara jakarta timur
# shm, lt / lb : 149 / 252, kondisi bangunan bagus, 2 lantai, 6+1 kamar tidur, air tanah, listrik 1300 + 1300, 3 kamar mandi, 1 kamar pembantu,
# garasi 1 mobil.
# 2603
# 17898
# rumah dijual jakarta utara dijual rumah di kawasan tanjung priok jakarta utara (belakang polres jakarta utara)
# spesifikasi :
# - luas tanah & bangunan : 192m2
# - banyak ruangan (siap dijadikan kantor)
# - carport
# - listrik 3.500watt & 2.200watt
# - air pam
# - sertifikat hak milik (shm)
# 3720
# 18202
# 51

# %%
df[df['electricity_desc']%100!=0]
# Out:
#        index  kamar_mandi  kamar  ...    gym  electricity_desc     listrik
# 212      331            5      5  ...  False                 4         NaN
# 224      353            5      5  ...  False                 4     13500.0
# 264      444            5      4  ...  False                 4      2200.0
# 346      604            6      6  ...  False                 4     16500.0
# 562      900            6      6  ...  False              2596      4400.0
# 588      932            6      5  ...  False                 4      4400.0
# 678     1046            6      6  ...  False                 4     10600.0
# 679     1047            4      4  ...  False                 3     10600.0
# 908     1333            5      6  ...  False                23      2200.0
# 1959    2607            5      4  ...  False                 4      2200.0
# 1980    2633            3      3  ...  False                18      1300.0
# 2686    3604            2      3  ...  False              3650      2200.0
# 3952    5762           11     12  ...  False               105      2200.0
# 4174    6020            5      6  ...  False               220       900.0
# 4664    6566            2      4  ...  False              2999         NaN
# 4758    6672            3      3  ...  False              3750      2200.0
# 5097    7105            4      7  ...  False              2603  13001300.0
# 5764    7950            7     13  ...  False              4613  33001300.0
# 5960    8198            4      5  ...  False              8430  48003500.0
# 5972    8213            3      8  ...  False               110      2200.0
# 6079    8343            7      8  ...  False               110      1300.0
# 6693    9759            3      3  ...  False                11      5500.0
# 7052   10540            3      4  ...  False              2950      2200.0
# 7965   12885            4     11  ...  False                 2      2200.0
# 8222   13390           20     20  ...  False                 2      7700.0
# 8517   13927            4      5  ...  False               220        10.0
# 8656   14097            5      5  ...  False                 2         NaN
# 8730   14183            2      3  ...  False                 1         0.0
# 10075  15791            5      4  ...  False                16        16.0
# 10148  15891            6      8  ...  False                10       100.0
# 10354  16198           30    108  ...  False               105        10.0
# 10447  16316           89    105  ...  False               105         0.0
# 10476  16372           89    105  ...  False               105         0.0
# 10538  16600            2      4  ...  False                16        16.0
# 10653  16761          130    106  ...  False              1406   1061300.0
# 11119  17406            2      3  ...  False              1520      1300.0
# 11532  17850            1      2  ...  False              1520       130.0
# 13168  19806            1      7  ...  False                90         0.0
# 13342  20022            1      7  ...  False                90        90.0
# 13791  20652            1      3  ...  False                 4         0.0
# 13916  20787            3      4  ...  False                11         2.0
# 14372  21308            5      5  ...  False                10        10.0
# 15338  22566            1      3  ...  False               450       450.0
# 15397  22663            1      3  ...  False               450       450.0
# 15414  22797            4      4  ...  False                 4      2200.0
# 15426  22809            4      4  ...  False                 4         0.0
# 15941  23353            4      4  ...  False                 4      2200.0
# 16875  24478            4      4  ...  False              2377      2200.0
# 17245  24976            4      7  ...  False              3720         NaN
# 17898  25927            4      7  ...  False              2603  13001300.0
# 18202  26344            5      5  ...  False              3720      2200.0
#
# [51 rows x 18 columns]

# %%
df['listrik'] = np.zeros(len(df))
for i in range(len(df)):
    if df['electricity'].iloc[i] != df['electricity_desc'].iloc[i]:
        if (df['electricity_desc'].iloc[i] % 100 == 0) & (df['electricity_desc'].iloc[i] != 0):
            df['listrik'].iloc[i] = df['electricity_desc'].iloc[i]
        else :
            df['listrik'].iloc[i] = df['electricity'].iloc[i]
# Out:
# /Users/rhzphlv/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df['listrik'].describe()
# Out:
# count     17699.000000
# mean       5056.749195
# std        8289.817056
# min          -1.000000
# 25%        2000.000000
# 50%        2200.000000
# 75%        4400.000000
# max      132000.000000
# Name: listrik, dtype: float64

# %%
df[df['listrik']>10]
# Out:
#        index  kamar_mandi  kamar  ...    gym  electricity_desc listrik
# 34        55            5      6  ...  False              6600  6600.0
# 51        78            4      4  ...  False              2200  2200.0
# 63        96            4      6  ...  False              3500  3500.0
# 84       135            3      4  ...  False              2200  2200.0
# 89       151            3      4  ...  False              2200  2200.0
# ...      ...          ...    ...  ...    ...               ...     ...
# 18224  26367            5      5  ...  False                 0  2200.0
# 18225  26368            5      5  ...  False                 0  2200.0
# 18226  26369            6      6  ...  False                 0  2200.0
# 18227  26370            5      5  ...  False                 0  2200.0
# 18228  26371            4      4  ...  False                 0  2200.0
#
# [15083 rows x 18 columns]
