# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns',False)
sns.set(rc={'figure.figsize':(20.7,8.27)})
sns.set_style("whitegrid")
sns.color_palette("dark")
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv('data_clean.csv')
df = df[df['tipe'] == 'Rumah']
df = df.drop(
    ['tipe','Unnamed: 0','deskripsi'],
    axis = 1
)
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12266 entries, 0 to 13495
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kamar_mandi    12266 non-null  int64
#  1   kamar_tidur    12266 non-null  int64
#  2   luas_bangunan  12266 non-null  float64
#  3   luas_tanah     12266 non-null  float64
#  4   harga          12266 non-null  float64
#  5   kecamatan      12266 non-null  object
#  6   garasi         12266 non-null  bool
#  7   kolam_renang   12266 non-null  bool
#  8   taman          12266 non-null  bool
#  9   gym            12266 non-null  bool
#  10  listrik        12266 non-null  float64
#  11  jumlah_lantai  12266 non-null  int64
# dtypes: bool(4), float64(4), int64(3), object(1)
# memory usage: 910.4+ KB

# %%
df_copy = df.copy()

# %%
cat = [i for i in df_copy.columns if df_copy[i].dtypes in ['O','bool']]
num = [i for i in df.columns if df[i].dtypes in ['int','float']]
df_copy[cat] = df_copy[cat].astype('O')

# %%
from feature_engine.encoding import OrdinalEncoder as OE

# %%
oe = OE(variables = [i for i in cat])
oe.fit(df_copy,df_copy['harga'])
# Out:
# OrdinalEncoder(variables=['kecamatan', 'garasi', 'kolam_renang', 'taman',
#                           'gym'])

# %%
df_copy = oe.transform(df_copy)

# %%
from sklearn.preprocessing import StandardScaler as ss

# %%
scale = ss()
scale.fit(df_copy)
df_copy = scale.transform(df_copy)

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

# %%
model = KMeans()
visualizer = KElbowVisualizer(
    model,
    k = (2,10),
    metric = 'calinski_harabasz',
    timing = False
)

# %%
visualizer.fit(df_copy)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Calinski Harabasz Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %%
model = KMeans(n_clusters=2)
cluster = model.fit_predict(df_copy)

# %%
df_copy = pd.DataFrame(df_copy)

# %%
df_copy.columns = df.columns

# %%
df_copy['cluster'] = cluster
df['cluster'] = cluster

# %%
def set_cluster(df):
    a = df[df['cluster'] == 0]['harga'].mean()
    b = df[df['cluster'] == 1]['harga'].mean()
    if a>b:
        df['cluster']=df['cluster'].apply(lambda x:1 if x==0 else 0)
    return df

# %%
df_copy = set_cluster(df_copy)
df = set_cluster(df)

# %%
plt.figure(figsize=(4,2), dpi=150)
df_copy.corr()['cluster'][:-1].sort_values().plot(kind='bar')
plt.show()

# %% [markdown]
# Cluster 0

# %%
df[df['cluster'] ==0][cat].describe()
# Out:
#           kecamatan garasi kolam_renang  taman    gym
# count         10005  10005        10005  10005  10005
# unique           42      2            2      2      2
# top     Duren Sawit   True        False  False  False
# freq            852   8664         9509   7953   9934

# %%
df[df['cluster'] ==0].describe()
# Out:
#         kamar_mandi   kamar_tidur  ...  jumlah_lantai  cluster
# count  10005.000000  10005.000000  ...   10005.000000  10005.0
# mean       3.455972      4.331134  ...       2.013793      0.0
# std        1.179249      1.328416  ...       0.648415      0.0
# min        1.000000      1.000000  ...       1.000000      0.0
# 25%        3.000000      3.000000  ...       2.000000      0.0
# 50%        3.000000      4.000000  ...       2.000000      0.0
# 75%        4.000000      5.000000  ...       2.000000      0.0
# max        9.000000     15.000000  ...       5.000000      0.0
#
# [8 rows x 8 columns]

# %%
for i in cat:
    print(i)
    df[df['cluster'] ==0][i].value_counts().plot.bar()
    plt.show()
# Out:
# kecamatan
# garasi
# kolam_renang
# taman
# gym

# %%
for i in num:
    print(i)
    df[df['cluster'] ==0][i].plot.hist(bins = 100)
    plt.show()
# Out:
# kamar_mandi
# kamar_tidur
# luas_bangunan
# luas_tanah
# harga
# listrik
# jumlah_lantai

# %% [markdown]
# Cluster 1

# %%
df[df['cluster'] == 1][cat].describe()
# Out:
#        kecamatan garasi kolam_renang  taman    gym
# count       2261   2261         2261   2261   2261
# unique        41      2            2      2      2
# top      Menteng   True        False  False  False
# freq         316   2150         1183   1644   2204

# %%
df[df['cluster'] == 1].describe()
# Out:
#        kamar_mandi  kamar_tidur  ...  jumlah_lantai  cluster
# count  2261.000000  2261.000000  ...    2261.000000   2261.0
# mean      5.605927     6.524547  ...       2.245909      1.0
# std       1.947529     2.902996  ...       0.733905      0.0
# min       1.000000     2.000000  ...       1.000000      1.0
# 25%       4.000000     5.000000  ...       2.000000      1.0
# 50%       5.000000     6.000000  ...       2.000000      1.0
# 75%       6.000000     7.000000  ...       3.000000      1.0
# max      28.000000    43.000000  ...       5.000000      1.0
#
# [8 rows x 8 columns]

# %%
for i in cat:
    print(i)
    df[df['cluster'] == 1][i].value_counts().plot.bar()
    plt.show()
# Out:
# kecamatan
# garasi
# kolam_renang
# taman
# gym

# %%
for i in num:
    print(i)
    df[df['cluster'] ==1][i].plot.hist(bins = 100)
    plt.show()
# Out:
# kamar_mandi
# kamar_tidur
# luas_bangunan
# luas_tanah
# harga
# listrik
# jumlah_lantai

# %% [markdown]
# Compare cluster 1 dan cluster 0

# %%
for i in num:
    print(i)
    plt.figure(figsize=(20,10),dpi=200)
    sns.histplot(data=df, x=i, bins=100, hue='cluster')
    plt.show()
# Out:
# kamar_mandi
# kamar_tidur
# luas_bangunan
# luas_tanah
# harga
# listrik
# jumlah_lantai

# %%
df_cat = pd.concat([df[cat],df['cluster']], axis = 1)
for i in cat:
    if i != 'kecamatan':
        print(i)
        df_cat = pd.concat([df[cat],df['cluster']], axis = 1)
        df_cat = pd.DataFrame(df_cat.groupby(['cluster'])[i].value_counts())
        df_cat.columns = ['count']
        df_cat['total_cluster'] = df_cat.groupby(['cluster'])['count'].transform('sum')
        df_cat['persentase'] = df_cat['count'] / df_cat['total_cluster']*100
        df_cat = df_cat.reset_index()
        sns.barplot(
            data = df_cat,
            x = i,
            y = 'persentase',
            hue = 'cluster'
        )
        plt.show()
# Out:
# garasi
# kolam_renang
# taman
# gym

# %%
df_kecamatan = df.groupby(['cluster','kecamatan'])[['harga']].count().reset_index()
df_kecamatan.columns = ['cluster', 'kecamatan', 'count']
df_kecamatan['total_cluster'] = df_kecamatan.groupby(['cluster'])['count'].transform('sum')
df_kecamatan['persentase'] = df_kecamatan['count']/df_kecamatan['total_cluster']*100
df_kecamatan = df_kecamatan[['cluster','kecamatan','persentase']]
plt.figure(figsize=(22,22),dpi=200)
sns.barplot(data=df_kecamatan, y='kecamatan',x='persentase', hue='cluster', order = df['kecamatan'].value_counts().index)
plt.title('Kecamatan per Cluster')
plt.show()

# %%
used = []
for i in num:
    for j in num:
        if (i != j) & (j not in used):
            print("var ", i,' ', j)
            sns.scatterplot(data=df, x=i, y=j, hue="cluster")
            plt.show()
    used.append(i)
# Out:
# var  kamar_mandi   kamar_tidur
# var  kamar_mandi   luas_bangunan
# var  kamar_mandi   luas_tanah
# var  kamar_mandi   harga
# var  kamar_mandi   listrik
# var  kamar_mandi   jumlah_lantai
# var  kamar_tidur   luas_bangunan
# var  kamar_tidur   luas_tanah
# var  kamar_tidur   harga
# var  kamar_tidur   listrik
# var  kamar_tidur   jumlah_lantai
# var  luas_bangunan   luas_tanah
# var  luas_bangunan   harga
# var  luas_bangunan   listrik
# var  luas_bangunan   jumlah_lantai
# var  luas_tanah   harga
# var  luas_tanah   listrik
# var  luas_tanah   jumlah_lantai
# var  harga   listrik
# var  harga   jumlah_lantai
# var  listrik   jumlah_lantai

# %%
used
# Out:
# ['kamar_mandi',
#  'kamar_tidur',
#  'luas_bangunan',
#  'luas_tanah',
#  'harga',
#  'listrik',
#  'jumlah_lantai']
