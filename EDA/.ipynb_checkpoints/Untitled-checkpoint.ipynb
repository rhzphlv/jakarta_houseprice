# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_columns',False)
sns.set(rc={'figure.figsize':(20.7,8.27)})
sns.set_style("whitegrid")
sns.color_palette("dark")
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv('../data/data.csv')
df = df.drop(['Unnamed: 0','Unnamed: 0.1'], axis = 1)
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24120 entries, 0 to 24697
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kamar_mandi    24120 non-null  object
#  1   kamar          24120 non-null  object
#  2   lb             23405 non-null  float64
#  3   lt             19667 non-null  float64
#  4   tipe_property  24120 non-null  object
#  5   price          24109 non-null  float64
#  6   sertifikat     24120 non-null  int64
#  7   deskripsi      24119 non-null  object
#  8   lokasi         23751 non-null  object
#  9   ada_garasi     24120 non-null  float64
#  10  pool           24120 non-null  int64
#  11  taman          24120 non-null  int64
#  12  electricity    23611 non-null  float64
#  13  floors_total   23939 non-null  float64
#  14  gym            24120 non-null  int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 2.9+ MB

# %%
df = df.dropna(subset = ['price','lokasi'])

# %%
df[['pool','taman','gym','sertifikat']] = df[['pool','taman','gym','sertifikat']].astype('bool')

# %%
df['ada_garasi'] = df['ada_garasi'].apply(lambda x: True if x > 0 else False)

# %%
num = [i for i in df.columns if df[i].dtypes in ['int','float']]
cat = [i for i in df.columns if df[i].dtypes == 'O']

# %%
for i in num:
    print(i)
    df[df['tipe_property']=="Rumah"][i].plot.hist(bins = 100)
    plt.show()
    df[df['tipe_property']=="Rumah"][i].plot.box()
    plt.show()
# Out:
# lb
# lt
# price
# electricity
# floors_total

# %%
df[df['tipe_property']=="Rumah"]
# Out:
#       kamar_mandi kamar      lb  ...  electricity floors_total    gym
# 0             3.0   3.0   240.0  ...          NaN          NaN  False
# 1             6.0   6.0  2700.0  ...          NaN          2.0  False
# 5             5.0   4.0   205.0  ...          NaN          2.0  False
# 6             2.0   3.0    90.0  ...          NaN          2.0  False
# 11            4.0   5.0   280.0  ...          NaN          2.0  False
# ...           ...   ...     ...  ...          ...          ...    ...
# 24693         2.0   3.0   100.0  ...       2200.0          2.0  False
# 24694         3.0   3.0   110.0  ...       2200.0          2.0  False
# 24695         3.0   3.0   130.0  ...       2200.0          2.0  False
# 24696         3.0   3.0   130.0  ...       1300.0          2.0  False
# 24697         3.0   3.0   130.0  ...       2200.0          2.0  False
#
# [17228 rows x 15 columns]

# %%
df[df['electricity']<20000]
# Out:
#       kamar_mandi kamar     lb     lt  ...  taman  electricity  floors_total    gym
# 349           3.0   4.0  119.0    NaN  ...  False      13500.0           1.0   True
# 350           4.0   5.0  140.0   80.0  ...  False      13500.0           1.0  False
# 351           2.0   2.0   80.0    NaN  ...   True      13500.0           1.0   True
# 352           5.0   5.0  140.0   92.0  ...  False      13500.0           2.0  False
# 353           5.0   5.0  160.0  117.0  ...  False      13500.0           2.0  False
# ...           ...   ...    ...    ...  ...    ...          ...           ...    ...
# 24693         2.0   3.0  100.0   63.0  ...  False       2200.0           2.0  False
# 24694         3.0   3.0  110.0   95.0  ...  False       2200.0           2.0  False
# 24695         3.0   3.0  130.0   95.0  ...  False       2200.0           2.0  False
# 24696         3.0   3.0  130.0   86.0  ...  False       1300.0           2.0  False
# ...

# %%
df[df['electricity']>4.400000e+07]['deskripsi'].iloc[0]
# Out:
# 'Rumah komplek Elite AL Strategis Duren Sawit Bu bawah Apraisal:Di Jual Rumah Besar Dalam Komplek Elite AL Dengan Tanah Taman Luas Di Duren Sawit Jakarta Timur.\n__\nLuas tanah 390 m2\nLuas bangunan 424 m2\nLegalitas SHM IMB\n7+1 kamar tidur\n5+1 kamar mandi\n__\nHarga : Rp 7,5 Mily TURUN MENJADI Rp 6 Mily Nego by Owner.\n__\nNoted : Nilai appraisal 2020 Rp 6,8 M-an\n__\nPosisi Hook dengan bangunan 2 lantai.\nMenghadap ke Timur\nCarport 2 mobil, garasi motor.\nListrik 4400 3500\nBangunan renov total 2015\n__\nTerdapat : Ruang Tamu, Ruang Makan, Ruang Keluarga, Mushola, Dapur, Gudang, Lantai untuk cuci dan jemur dengan kamar asisten yang terpisah.\n__\nRumah ini juga (di desain khusus) memiliki sirkulasi cahaya dan udara yang sangat maksimal menjadikan setiap ruangan dalam rumah ini mendapat sirkulasi cahaya dan udara yang sangat memadai.\n__\nSelling points :\n- 10 mnt dari Tol Becakayu dan Tol Halim - Cikampek.\n- 10 mnt dari Mall Cipinang.\n- 20 mnt dari Bandara Halim.\n- Bebas ban
# ...

# %%
df[df['electricity']>4.400000e+07]['electricity'].iloc[0] = 7900
# Out:
# <ipython-input-12-f50422299ca7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['electricity']>4.400000e+07]['electricity'].iloc[0] = 7900

# %%
df['electricity'].describe()
# Out:
# count    2.324100e+04
# mean     7.157895e+03
# std      2.887831e+05
# min     -1.000000e+00
# 25%      1.300000e+03
# 50%      2.200000e+03
# 75%      4.400000e+03
# max      4.400350e+07
# Name: electricity, dtype: float64

# %%
df['lokasi'].value_counts().plot.bar()

# %%
df.drop_duplicates()
# Out:
#       kamar_mandi kamar      lb  ...  electricity floors_total    gym
# 0             3.0   3.0   240.0  ...          NaN          NaN  False
# 1             6.0   6.0  2700.0  ...          NaN          2.0  False
# 2             6.0   6.0     NaN  ...          NaN          2.0  False
# 3             6.0   6.0     NaN  ...          NaN          2.0  False
# 4             6.0   6.0     NaN  ...          NaN          2.0  False
# ...           ...   ...     ...  ...          ...          ...    ...
# 24693         2.0   3.0   100.0  ...       2200.0          2.0  False
# 24694         3.0   3.0   110.0  ...       2200.0          2.0  False
# 24695         3.0   3.0   130.0  ...       2200.0          2.0  False
# 24696         3.0   3.0   130.0  ...       1300.0          2.0  False
# 24697         3.0   3.0   130.0  ...       2200.0          2.0  False
#
# [23741 rows x 15 columns]

# %%
df[df['lokasi']=='Koja']
# Out:
#       kamar_mandi kamar     lb      lt  ...  taman  electricity  floors_total    gym
# 2878          3.0   3.0    NaN     NaN  ...  False       4400.0           2.0  False
# 3021          2.0   3.0  200.0   240.0  ...  False       4400.0           2.0  False
# 3089          2.0   5.0  120.0   140.0  ...  False       4400.0           3.0  False
# 3321          4.0   5.0  200.0   189.0  ...  False       2200.0           3.0  False
# 3749          3.0   7.0  180.0   136.0  ...  False       2200.0           1.0  False
# 3921          3.0   4.0  150.0   184.0  ...  False       2200.0           3.0  False
# 4419          3.0   3.0  100.0   155.0  ...  False       1300.0           1.0  False
# 4700          4.0   6.0  200.0   180.0  ...   True      40000.0           2.0  False
# 5472          4.0   4.0    NaN  2900.0  ...  False       2200.0           2.0  False
# 13858           4     4  160.0   112.0  ...  False          0.0           2.0  False
# ...
