# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns',False)
sns.set(rc={'figure.figsize':(20.7,8.27)})
sns.set_style("whitegrid")
sns.color_palette("dark")
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv('data_bersih_ver3.csv')
df['kamar'] = df['kamar_mandi'] + df['kamar_tidur']
df['km:k'] = df['kamar_mandi'] / df['kamar']
df['lb:lt'] =  df['luas_bangunan'] / df['luas_tanah']
df = df[df['tipe']=='Rumah']
df = df.drop(
    ['Unnamed: 0', 'tipe','kamar_mandi','luas_bangunan','taman','garasi','kamar_tidur','jumlah_lantai'], 
    axis = 1
)
df.drop_duplicates()
# Out:
#        luas_tanah         harga         kecamatan  ...  kamar      km:k     lb:lt
# 0           155.0  6.700000e+09  Mampang Prapatan  ...     11  0.454545  2.277419
# 1            60.0  1.299000e+09          Cilandak  ...      8  0.500000  1.500000
# 2           109.0  2.300000e+09    Kebayoran Baru  ...     10  0.400000  1.467890
# 3            72.0  3.149480e+09  Mampang Prapatan  ...      7  0.428571  1.736111
# 4            87.0  1.210000e+09         Jagakarsa  ...      7  0.428571  1.034483
# ...           ...           ...               ...  ...    ...       ...       ...
# 13487        60.0  1.292000e+09              Koja  ...      7  0.428571  1.216667
# 13492       320.0  8.800000e+09              Koja  ...     10  0.500000  0.781250
# 13493       173.0  2.950000e+09              Koja  ...     12  0.500000  1.445087
# 13494        75.0  1.750000e+09              Koja  ...     10  0.500000  1.293333
# 13495       331.0  7.700000e+09              Koja  ...      8  0.500000  1.075529
#
# [12160 rows x 9 columns]

# %%
df_copy = df.copy()

# %%
cat = [i for i in df_copy.columns if df_copy[i].dtypes in ['O','bool']]
df_copy[cat] = df_copy[cat].astype('O')

# %%
from feature_engine.encoding import DecisionTreeEncoder as DTE

# %%
encode = DTE(variables = ['kecamatan'])
encode.fit(df_copy,df_copy['harga'])
# Out:
# DecisionTreeEncoder(param_grid={'max_depth': [1, 2, 3, 4]},
#                     variables=['kecamatan'])

# %%
df_copy = encode.transform(df_copy)
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12765 entries, 0 to 13495
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   luas_tanah    12765 non-null  float64
#  1   harga         12765 non-null  float64
#  2   kecamatan     12765 non-null  float64
#  3   kolam_renang  12765 non-null  object
#  4   gym           12765 non-null  object
#  5   listrik       12765 non-null  float64
#  6   kamar         12765 non-null  int64
#  7   km:k          12765 non-null  float64
#  8   lb:lt         12765 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 997.3+ KB

# %%
from feature_engine.encoding import OrdinalEncoder as OE

# %%
oe = OE(variables = [i for i in cat if i != 'kecamatan'])
oe.fit(df_copy,df_copy['harga'])
# Out:
# OrdinalEncoder(variables=['kolam_renang', 'gym'])

# %%
df_copy = oe.transform(df_copy)

# %%
from sklearn.preprocessing import StandardScaler as ss

# %%
scale = ss()
scale.fit(df_copy)
df_copy = scale.transform(df_copy)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %%
model = KMeans()
visualizer = KElbowVisualizer(
    model,
    k = (2,5),
    metric = 'calinski_harabasz',
    timing = False
)

# %%
visualizer.fit(df_copy)
visualizer.show()

# %%
model = KMeans(n_clusters=2)
cluster = model.fit_predict(df_copy)

# %%
df_copy = pd.DataFrame(df_copy)
df_copy.columns = df.columns

# %%
df_copy['cluster'] = cluster

# %%
plt.figure(figsize=(5,2), dpi=200)
df_copy.corr()['cluster'][:-1].abs().sort_values().plot(kind='bar')
