# %%
# ### Code for scrapping from one page

# #Starts up our Driver and loads up our starting webpage
# from selenium import webdriver
# import time

# path = r'C:\Users\dosal\Downloads\Buat_Dede\My_Udemy_BuatDede\Web_Scrapping_with_Python_With_BeautifulSoup_and_Selenium_2021/chromedriver.exe'
# driver = webdriver.Chrome(path)

# driver.get(
# #     'https://www.rumah123.com/properti/jakarta-pusat/hos8220289/'
# #     'https://www.rumah123.com/properti/jakarta-pusat/hos8203587/'
# #     'https://www.rumah123.com/properti/jakarta-pusat/hos6051656/'
# #     'https://www.rumah123.com/properti/jakarta-pusat/hos8212207/'
# #     'https://www.rumah123.com/properti/jakarta-pusat/hos8215191/'
#     'https://www.rumah123.com/properti/jakarta-pusat/hos8212207/'
# )
          

# kamus = {}


# ## Harga/Lokasi
# try:
#     xpath_price = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/span'
#     price = driver.find_element_by_xpath(xpath_price).text
#     kamus['harga'] = price
# except:
#     kamus['harga'] = ''

# try:
#     xpath_loc = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[2]/h1' 
#     loc = driver.find_element_by_xpath(xpath_loc).text
#     kamus['location'] = loc
# except:
#     kamus['location'] = ''


# ## Luas Bangunan/Luas Tanah
# try:
#     xpath_lb = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[3]/div/div/div/div[1]/a/span'
#     lb = driver.find_element_by_xpath(xpath_lb).text
#     kamus['lb'] = lb
# except:
#     kamus['lb'] = ''

# try:
#     xpath_lt = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[3]/div/div/div/div[2]/a/span'
#     lt = driver.find_element_by_xpath(xpath_lt).text
#     kamus['lt'] = lt
# except:
#     kamus['lt'] = ''

    
# ## KT/KM/Garasi
# try:
#     xpath_kt = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div/div[1]/a/span[2]'
#     kt = driver.find_element_by_xpath(xpath_kt).text
#     kamus['kt'] = kt
# except:
#     kamus['kt'] = ''

# try:
#     xpath_km = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div/div[2]/a/span[2]'
#     km = driver.find_element_by_xpath(xpath_km).text
#     kamus['km'] = km
# except:
#     kamus['km'] = ''

# try:
#     xpath_car = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div/div[3]/a/span[2]'
#     car = driver.find_element_by_xpath(xpath_car).text
#     kamus['car'] = car
# except:
#     kamus['car'] = ''

# # Klik menampilkan lebih banyak untuk kolom Deskripsi
# keklik = False
# cobaklik = 0
# while keklik == False and cobaklik < 20:
#     try:
#         button = driver.find_element_by_xpath(
#             '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[2]/div[1]/div[2]/span')
# #         '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[2]/div[1]/div[2]')
#         button.click()
#         print("Expand kolom deskripsi")
#         keklik = True
#     except:
#         cobaklik += 1

# if keklik == False:
#     print("Gagal menampilkan lebih banyak KOLOM DESKRIPSI atau button memang tidak ada")

# # Judul Deskripsi/Deskripsi Kalau ada peta
# ada_peta = True
# try:
#     xpath_jdl = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/div[2]/h2'
#     jdl = driver.find_element_by_xpath(xpath_jdl).text
# except:
#     jdl = ''
#     ada_peta = False

# try:
#     xpath_desc = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/div[2]/div[1]/div[1]/p'
#     desc = driver.find_element_by_xpath(xpath_desc).text
#     kamus['Deskripsi'] = jdl + ':' + desc
# except:
#     kamus['Deskripsi'] = ''
#     ada_peta = False

# if ada_peta == False:
#     # Judul Deskripsi/Deskripsi Kalau tidak ada peta
#     try:
#         xpath_jdl = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/h2'
#         jdl = driver.find_element_by_xpath(xpath_jdl).text
#     except:
#         jdl = ''

#     try:
#         xpath_desc = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/div[1]/div[1]/p'
#         desc = driver.find_element_by_xpath(xpath_desc).text
#         kamus['Deskripsi'] = jdl + ':' + desc
#     except:
#         kamus['Deskripsi'] = ''


# ## Klik Menampilkan Lebih banyak untuk kolom detil/info properti
# keklik = False
# cobaklik = 0
# while keklik == False and cobaklik < 20:
#     try:
#         button = driver.find_element_by_xpath(
#           '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[2]/div/div[2]/div[2]/span')
#     #         '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[2]/div[1]/div[2]/span')
#         button.click()
#         print("Berhasil menampilkan lebih banyak KOLOM PROPERTI")
#         keklik = True
#     except:
#         cobaklik += 1

# if keklik == False:
#     print("Gagal menampilkan lebih banyak atau button memang tidak ada")

# ## Detil Properti
# for i in range(1,15):
#     try:
#         xpath_nama_info = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[2]/div/div[2]/div[1]/div/div/div['+str(i)+']/p[1]'
#         nama_info = driver.find_element_by_xpath(xpath_nama_info).text
#         xpath_info = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[2]/div/div[2]/div[1]/div/div/div['+str(i)+']/p[2]'
#         info = driver.find_element_by_xpath(xpath_info).text
#         kamus[nama_info] = info
#     except:
#         break
        
# print('Selesai')
# driver.quit()

# kamus
# Out:
# Gagal menampilkan lebih banyak KOLOM DESKRIPSI atau button memang tidak ada
# Gagal menampilkan lebih banyak atau button memang tidak ada
# Selesai
# {'harga': 'Rp. 25.000.000.000',
#  'location': 'Senen, Jakarta Pusat',
#  'lb': 'Luas Bangunan : 1553 m²',
#  'lt': 'Luas Tanah : 774 m²',
#  'kt': '106',
#  'km': '51',
#  'car': '',
#  'Deskripsi': 'CHANDRA*rumah kost bagus lt 774m2 lokasi strategis di senen:Mengapa Kost Ekslusif Flamboyan ini beda dari yg lain?\n- Kost Mewah Instagramable\n- Beli 1 Kost 106 kamar Gratis 1 Kost 10 kamar\n- Kost Full Okupansi\n- Harga Dibawah Pasar (Appresal BCA 2018 25 M masi Gratis 1 Kost lagi)\n- Investasi Tahan Krisis (transaksi bln ini , bln depan terima uang )\n\nBrand new kostan\n"The Ekslusif Flamboyan" Senen\nLt.774 /1553 m2(4 lt)\nKT 106(token semua) KM 51\nHarga sewa 1 jt - 3 jt/bln\nFasilitas : AC,Free Wifi,Tv,Cafe,Kantin,Resepsionis,Access Card,Cctv.\nDok SHM,IMB,PBB lengkap\n\nLokasi strategis :\n- Blkg hotel Acacia\n- dekat Menteng\n- dekat RSCM\n- dekat Atrium Senen\n- dekat Pasar Kenari\n- dekat Halte Busway\nHarga 25 M(Nego)Gratis Kost\n\nKpr bank dibantu\nHub chandra 08128169168\nFollow my IG @chandrajelambar',
#  'ID Iklan': 'hos8212207',
#  'Tipe Properti': 'Rumah',
#  'Jumlah Lantai': '4',
#  'Sertifikat': 'SHM - Sertifikat Hak Milik',
#  'Tanggal Tayang': '23 April 2021'}

# %%
# ### Load links from rumah.txt
# my_file = open('rumah.txt')
# my_file.seek(0)
# links = my_file.readlines()
# my_file.close()
# links = [link[:-2] for link in links]
# links[:10]
# Out:
# ['https://www.rumah123.com/properti/jakarta-pusat/hos8220289',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos8203587',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos8264752',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos8236689',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos8215191',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos8142110',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos8071827',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos8225178',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos6051656',
#  'https://www.rumah123.com/properti/jakarta-pusat/hos2416392']

# %%
### Code for scrapping from bunch of pages

### Load links from rumah.txt
my_file = open('rumah.txt')
my_file.seek(0)
links = my_file.readlines()
my_file.close()
links = [link[:-2] for link in links]
links = links[1:5]

#Starts up our Driver and loads up our starting webpage
from selenium import webdriver
# import time

data = {}
for link in links:
    path = r'C:\Users\dosal\Downloads\Buat_Dede\My_Udemy_BuatDede\Web_Scrapping_with_Python_With_BeautifulSoup_and_Selenium_2021/chromedriver.exe'
    driver = webdriver.Chrome(path)
    driver.get(link)

    kamus = {}
    ## Harga/Lokasi
    try:
        xpath_price = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/span'
        price = driver.find_element_by_xpath(xpath_price).text
        kamus['harga'] = price
    except:
        kamus['harga'] = ''

    try:
        xpath_loc = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[2]/h1' 
        loc = driver.find_element_by_xpath(xpath_loc).text
        kamus['location'] = loc
    except:
        kamus['location'] = ''


    ## Luas Bangunan/Luas Tanah
    try:
        xpath_lb = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[3]/div/div/div/div[1]/a/span'
        lb = driver.find_element_by_xpath(xpath_lb).text
        kamus['lb'] = lb
    except:
        kamus['lb'] = ''

    try:
        xpath_lt = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[3]/div/div/div/div[2]/a/span'
        lt = driver.find_element_by_xpath(xpath_lt).text
        kamus['lt'] = lt
    except:
        kamus['lt'] = ''


    ## KT/KM/Garasi
    try:
        xpath_kt = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div/div[1]/a/span[2]'
        kt = driver.find_element_by_xpath(xpath_kt).text
        kamus['kt'] = kt
    except:
        kamus['kt'] = ''

    try:
        xpath_km = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div/div[2]/a/span[2]'
        km = driver.find_element_by_xpath(xpath_km).text
        kamus['km'] = km
    except:
        kamus['km'] = ''

    try:
        xpath_car = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div/div[3]/a/span[2]'
        car = driver.find_element_by_xpath(xpath_car).text
        kamus['car'] = car
    except:
        kamus['car'] = ''

    # Klik menampilkan lebih banyak untuk kolom Deskripsi
    keklik = False
    cobaklik = 0
    while keklik == False and cobaklik < 20:
        try:
            button = driver.find_element_by_xpath(
                '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[2]/div[1]/div[2]/span')
    #         '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[2]/div[1]/div[2]')
            button.click()
            print("Expand kolom deskripsi")
            keklik = True
        except:
            cobaklik += 1

    if keklik == False:
        print("Gagal menampilkan lebih banyak KOLOM DESKRIPSI atau button memang tidak ada")

    # Judul Deskripsi/Deskripsi Kalau ada peta
    ada_peta = True
    try:
        xpath_jdl = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/div[2]/h2'
        jdl = driver.find_element_by_xpath(xpath_jdl).text
    except:
        jdl = ''
        ada_peta = False

    try:
        xpath_desc = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/div[2]/div[1]/div[1]/p'
        desc = driver.find_element_by_xpath(xpath_desc).text
        kamus['Deskripsi'] = jdl + ':' + desc
    except:
        kamus['Deskripsi'] = ''
        ada_peta = False

    if ada_peta == False:
        # Judul Deskripsi/Deskripsi Kalau tidak ada peta
        try:
            xpath_jdl = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/h2'
            jdl = driver.find_element_by_xpath(xpath_jdl).text
        except:
            jdl = ''

        try:
            xpath_desc = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[1]/div/div[1]/div[1]/p'
            desc = driver.find_element_by_xpath(xpath_desc).text
            kamus['Deskripsi'] = jdl + ':' + desc
        except:
            kamus['Deskripsi'] = ''


    ## Klik Menampilkan Lebih banyak untuk kolom detil/info properti
    keklik = False
    cobaklik = 0
    while keklik == False and cobaklik < 20:
        try:
            button = driver.find_element_by_xpath(
              '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[2]/div/div[2]/div[2]/span')
        #         '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[2]/div[1]/div[2]/span')
            button.click()
            print("Berhasil menampilkan lebih banyak KOLOM PROPERTI")
            keklik = True
        except:
            cobaklik += 1

    if keklik == False:
        print("Gagal menampilkan lebih banyak KOLOM PROPERTI atau button memang tidak ada")

    ## Detil Properti
    for i in range(1,15):
        try:
            xpath_nama_info = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[2]/div/div[2]/div[1]/div/div/div['+str(i)+']/p[1]'
            nama_info = driver.find_element_by_xpath(xpath_nama_info).text
            xpath_info = '//*[@id="99-root-app"]/div/div/div[2]/div[2]/div[3]/div/div/div[2]/div/div[2]/div[1]/div/div/div['+str(i)+']/p[2]'
            info = driver.find_element_by_xpath(xpath_info).text
            kamus[nama_info] = info
        except:
            break

    print(f'Scrapping link {link} Selesai')
    driver.quit()
    data[link] = kamus
    print(kamus)
    print("\n")
# Out:
# Gagal menampilkan lebih banyak KOLOM DESKRIPSI atau button memang tidak ada
# Berhasil menampilkan lebih banyak KOLOM PROPERTI
# Scrapping link https://www.rumah123.com/properti/jakarta-pusat/hos8203587 Selesai
# {'harga': 'Rp. 150.000.000.000', 'location': 'Menteng, Jakarta Pusat', 'lb': 'Luas Bangunan : 480 m²', 'lt': 'Luas Tanah : 786 m²', 'kt': '3', 'km': '2', 'car': '', 'Deskripsi': 'COMPOUND HOUSE MENTENG JAKARTA PUSAT. PREMIUM LOCATION:[ FOR SALE ] COMPOUND HOUSE MENTENG JAKARTA PUSAT.\nPREMIUM LOCATION\n\nSPESIFIKASI\nLuas Tanah 786m2\nLuas Bangunan 480m2\nTerdiri 4 Unit Rumah\nBangunan 2 Lantai\nKamar tidur 3+1\nKamar mandi 2+1\nShm imb Pbb\nAC tiap ruangan\npencahayaan matahari bagus\nView Timur\nCarport 10 mobil\n\nHarga Rp 150 M Negoo\n\nMore info\nDenri\n0817161219', 'ID Iklan': 'hos8203587', 'Tipe Properti': 'Rumah', 'Dilengkapi Perabotan': 'Semi Furnished', 'Kondisi Properti': 'Bagus Sekali', 'Jumlah Lantai': '2', 'Kamar Pembantu': '1', 'Kamar Mandi Pembantu': '1', 'Sertifikat': 'SHM - Sertifikat Hak Milik', 'Tanggal Tayang': '21 April 2021'}
#
#
# Gagal menampilkan lebih banyak KOLOM DESKRIPSI atau button memang tidak ada
# Berhasil menampilkan lebih banyak KOLOM PROPERTI
# Scrapping link https://www.rumah123.com/properti/jakarta-pusat/hos8264752 Selesai
# {'harga': 'Rp. 25.000.000.000', 'location': 'Senen, Jakarta Pusat', 'lb': 'Luas Bangunan : 1553 m²', 'lt': 'Luas Tanah : 774 m²', 'kt': '106', 'km': '51', 'car': '', 'Deskripsi': 'Beli Kost Bonus 1 Kost Lagi, Mewah, Occupancy penuh,Investasi Bagus, lokasi strategis, Instagramble:Beli Kost Bonus 1 kost lagi\nHarga dibawah Pasaran\n\nAyo Kapan lagi dapat Kesempatan langka ini\n\nKeunggulan Apa yang kita dapat?\n*Brand New Kost an\n*Kost Mewah Instagramable\n*Beli 1 Kost 106 kamar Gratis 1 Kost 10 kamar\n*Kost Full Okupansi\n*Harga Dibawah Pasar (Appresal BCA 2018 25 M masi Gratis 1 Kost lagi)\n*Investasi Tahan Krisis (transaksi\nbln ini , bln depan terima uang )\n\n*Lokasi Strategis\n- Blkg hotel Acacia\n- dekat Menteng\n- dekat RSCM\n- dekat Atrium Senen\n- dekat Pasar Kenari\n- dekat Halte Busway\n\n*Fasilitas : AC,Free Wifi,Tv,Cafe,Kantin,Resepsionis,Access Card,Cctv.\n*Dokumen Lengkap : Sertifikat SHM, IMB, dan PBB\n*Harga Sewa : 1-3juta/bln\n*Omzet diatas M an lebih\n\nSpesifikasi :\n4 lantai\nLT : 774 m2\nLB : 1553 m2\nKT : 106 ( token semua)\nKM: 51\nFasilitas : AC,Free Wifi,Tv,Cafe,Kantin,Resepsionis,Access Card,Cctv.\n\n\nBONUS 1 KOST LAGI\nKost Pademangan dengan 10 kmr\n\n\nHarga : 25 M\n\nAppresal BCA 2018 25 M\n\nInfo Selanjutnya :\nJunison\nWM PRO\n\nHP/WA : 082368-4949-01', 'ID Iklan': 'hos8264752', 'Tipe Properti': 'Rumah', 'Dilengkapi Perabotan': 'Furnished', 'Kondisi Properti': 'Sudah Renovasi', 'Jumlah Lantai': '4', 'Kamar Pembantu': '2', 'Kamar Mandi Pembantu': '2', 'Sertifikat': 'SHM - Sertifikat Hak Milik', 'Daya Listrik': '16500', 'Tanggal Tayang': '5 Mei 2021'}
#
#
# Gagal menampilkan lebih banyak KOLOM DESKRIPSI atau button memang tidak ada
# Berhasil menampilkan lebih banyak KOLOM PROPERTI
# Scrapping link https://www.rumah123.com/properti/jakarta-pusat/hos8236689 Selesai
# {'harga': 'Rp. 1.445.000.000', 'location': 'Gunung Sahari, Jakarta Pusat', 'lb': 'Luas Bangunan : 89 m²', 'lt': 'Luas Tanah : 44 m²', 'kt': '3', 'km': '2', 'car': '', 'Deskripsi': 'rumah minimalis gunung sahari dekat dengan pusat perbelanjaan mangga dua:Di Jual Rumah Baru Mewah Dan Elegant Di Jl Industri Gunung Sahari\nRumah Semi Claster di Gunung Sahari dengan suasana yang sangat nyaman dan menarik dengan kualitas bangunan terbaik\n\nRumah Semi Cluster di gunung sahari adalah perumahan cantik dengan bangunan 2 Lantai\n\nspesifikasi:\n- carpot, Ruang tamu, dapur, kamar mandi\n- kamar utama, kamar anak & kamar mandi\n\nspesifikasi tekniks\n- pondasi plat beton bertulang\n- Dinding doubel heble di plaster di aci dan di\ncat\n- cat vinilex\n- listrik 2200 watt\n- lampu down light\n- lantai granit 60X60\n- plafon holow gypsum\n- kamar mandi Sanitari closed duduk American standart,shower, hexospen\n- Air PDAM\n- instalasi Ac\n- instalasi water heater\n- Rangka atap baja ringan\n- Genteng multi roop\n- Tampilan rumah one gate system\n\nCara bayar:\ncash keras\ncash bertahap\nKPR\n\nyang berminat bisa langsung hubungi nita :0812.9178.0563(ruma', 'ID Iklan': 'hos8236689', 'Tipe Properti': 'Rumah', 'Dilengkapi Perabotan': 'Unfurnished', 'Kondisi Properti': 'Baru', 'Jumlah Lantai': '2', 'Sertifikat': 'SHM - Sertifikat Hak Milik', 'Daya Listrik': '2200', 'Tanggal Tayang': '28 April 2021'}
#
#
# Gagal menampilkan lebih banyak KOLOM DESKRIPSI atau button memang tidak ada
# Berhasil menampilkan lebih banyak KOLOM PROPERTI
# Scrapping link https://www.rumah123.com/properti/jakarta-pusat/hos8215191 Selesai
# {'harga': 'Rp. 1.750.000.000', 'location': 'Cempaka Putih, Jakarta Pusat', 'lb': 'Luas Bangunan : 97 m²', 'lt': 'Luas Tanah : 49 m²', 'kt': '2', 'km': '1', 'car': '', 'Deskripsi': 'rumah minimalis cempaka putih tengah strategis dekat pusat kuliner taman solo:Rumah Murah Modern Di Cempaka Putih, Jakarta Pusat DI JUAL !! "RUMAH MURAH MINIMALIS - CEMPAKA PUTIH TENGAH " Jakarta Pusat Rumah 2 Lantai atau 3 lantai dgn Akses strategis, Lingkungan Nyaman & Aman. - Harga Rp 1.750M - - Legal document : SHM - - Luas Tanah :97m2. luas bangunan 97 (notes:rumah masih indent estimasi pembangunan 8-10bln) Spesifikasi : - 2 Lantai - 3 Kamar Tidur - 1 Kamar Mandi - 1 Ruang Keluarga - 1 Dapur - 1 Carport - Instalasi AC - Instalasi Water Heater - Listrik : 2200 Watt - Air : PDAM + Pompa Other spek : - Pondasi : Ceker Ayam Plat beton - Struktur : Beton Bertulang - Rangka Atap : Baja Ringan - Genteng : Metal Multiroof - Dinding : Hebel (Double', 'ID Iklan': 'hos8215191', 'Tipe Properti': 'Rumah', 'Dilengkapi Perabotan': 'Unfurnished', 'Kondisi Properti': 'Bagus Sekali', 'Jumlah Lantai': '3', 'Sertifikat': 'SHM - Sertifikat Hak Milik', 'Daya Listrik': '2200', 'Tanggal Tayang': '27 April 2021'}

# %%
# for data_rumah in data.values():
import pandas as pd
list_data = list(data.values())

df = pd.DataFrame(list_data) 
df
# Out:
#                  harga                      location                       lb  \
# 0  Rp. 150.000.000.000        Menteng, Jakarta Pusat   Luas Bangunan : 480 m²
# 1   Rp. 25.000.000.000          Senen, Jakarta Pusat  Luas Bangunan : 1553 m²
# 2    Rp. 1.445.000.000  Gunung Sahari, Jakarta Pusat    Luas Bangunan : 89 m²
# 3    Rp. 1.750.000.000  Cempaka Putih, Jakarta Pusat    Luas Bangunan : 97 m²
#
#                     lt   kt  km car  \
# 0  Luas Tanah : 786 m²    3   2
# 1  Luas Tanah : 774 m²  106  51
# 2   Luas Tanah : 44 m²    3   2
# 3   Luas Tanah : 49 m²    2   1
#
#                                            Deskripsi    ID Iklan  \
# 0  COMPOUND HOUSE MENTENG JAKARTA PUSAT. PREMIUM ...  hos8203587
# 1  Beli Kost Bonus 1 Kost Lagi, Mewah, Occupancy ...  hos8264752
# 2  rumah minimalis gunung sahari dekat dengan pus...  hos8236689
# 3  rumah minimalis cempaka putih tengah strategis...  hos8215191
#
#   Tipe Properti Dilengkapi Perabotan Kondisi Properti Jumlah Lantai  \
# 0         Rumah       Semi Furnished     Bagus Sekali             2
# 1         Rumah            Furnished   Sudah Renovasi             4
# 2         Rumah          Unfurnished             Baru             2
# 3         Rumah          Unfurnished     Bagus Sekali             3
#
#   Kamar Pembantu Kamar Mandi Pembantu                  Sertifikat  \
# 0              1                    1  SHM - Sertifikat Hak Milik
# 1              2                    2  SHM - Sertifikat Hak Milik
# 2            NaN                  NaN  SHM - Sertifikat Hak Milik
# 3            NaN                  NaN  SHM - Sertifikat Hak Milik
#
#   Tanggal Tayang Daya Listrik
# 0  21 April 2021          NaN
# 1     5 Mei 2021        16500
# 2  28 April 2021         2200
# 3  27 April 2021         2200
